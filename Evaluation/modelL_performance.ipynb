# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/miniproject1 68/miniproject/miniproject_yolov12l/results.csv')
df
# Out:
#     epoch      time  train/box_loss  train/cls_loss  train/dfl_loss  \
# 0       1   100.162         1.31699         1.46620         1.49490
# 1       2   202.703         1.17280         1.02600         1.38844
# 2       3   337.180         1.20592         0.99987         1.42258
# 3       4   433.657         1.19448         0.97556         1.40894
# 4       5   542.611         1.11494         0.90101         1.34597
# 5       6   654.326         1.10158         0.90005         1.34784
# 6       7   767.722         1.09992         0.84031         1.34553
# 7       8   879.800         1.08766         0.81236         1.34189
# 8       9   977.140         1.07970         0.78587         1.33139
# 9      10  1101.100         1.05142         0.77147         1.31557
# 10     11  1210.000         1.04681         0.75304         1.29772
# 11     12  1307.080         1.03831         0.74211         1.31225
# 12     13  1409.970         1.02546         0.71552         1.29513
# ...

# %%
new_df = df.filter(items=['epoch','metrics/recall(B)'	,'metrics/mAP50(B)','metrics/mAP50-95(B)'])
new_df.tail()
# Out:
#     epoch  metrics/recall(B)  metrics/mAP50(B)  metrics/mAP50-95(B)
# 25     26            0.91380           0.92487              0.71839
# 26     27            0.88542           0.92641              0.71754
# 27     28            0.90831           0.91389              0.71694
# 28     29            0.91063           0.92953              0.72944
# 29     30            0.92241           0.93174              0.72905

# %%
new_df = df.filter(items=['train/box_loss',	'train/cls_loss',	'train/dfl_loss'])
new_df.tail()
# Out:
#     train/box_loss  train/cls_loss  train/dfl_loss
# 25         0.87455         0.47274         1.23576
# 26         0.86077         0.46501         1.22366
# 27         0.85154         0.44797         1.22165
# 28         0.83974         0.43309         1.20904
# 29         0.83404         0.42018         1.20143

# %%
from PIL import Image

# %%
results = Image.open('/content/drive/MyDrive/miniproject1 68/miniproject/miniproject_yolov12l/results.png')
results
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2400x1200>

# %%
n_matrix = Image.open('/content/drive/MyDrive/miniproject1 68/miniproject/miniproject_yolov12l/confusion_matrix_normalized.png')
n_matrix
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=3000x2250>

# %%
pr = Image.open('/content/drive/MyDrive/miniproject1 68/miniproject/miniproject_yolov12l/BoxPR_curve.png')
pr
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2250x1500>

# %%
f1 = Image.open('/content/drive/MyDrive/miniproject1 68/miniproject/miniproject_yolov12l/BoxF1_curve.png')
f1
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2250x1500>
