# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/miniproject1 68/miniproject/miniproject_yolov12m/results.csv')
df
# Out:
#     epoch       time  train/box_loss  train/cls_loss  train/dfl_loss  \
# 0       1    85.6581         1.32584         1.49393         1.41471
# 1       2   149.0960         1.18291         1.05748         1.32817
# 2       3   212.1600         1.16382         1.00687         1.34082
# 3       4   275.1800         1.15061         0.95091         1.34641
# 4       5   338.2050         1.12572         0.89317         1.32063
# 5       6   401.4390         1.09723         0.89425         1.30625
# 6       7   464.3510         1.08101         0.84789         1.28936
# 7       8   527.1030         1.08594         0.81500         1.30768
# 8       9   595.9770         1.06351         0.78336         1.27967
# 9      10   663.1740         1.04573         0.77234         1.27077
# 10     11   733.8960         1.03733         0.75284         1.25421
# 11     12   796.9350         1.02905         0.74655         1.26324
# 12     13   866.3780         1.01843         0.71291         1.25112
# ...

# %%
new_df = df.filter(items=['epoch','metrics/precision(B)','metrics/recall(B)','metrics/mAP50(B)','metrics/mAP50-95(B)'])
new_df.tail()
# Out:
#     epoch  metrics/precision(B)  metrics/recall(B)  metrics/mAP50(B)  \
# 25     26               0.91743            0.90367           0.93334
# 26     27               0.90069            0.90030           0.92331
# 27     28               0.89331            0.88765           0.90525
# 28     29               0.91812            0.91519           0.93935
# 29     30               0.91191            0.91134           0.93824
#
#     metrics/mAP50-95(B)
# 25              0.72655
# 26              0.72401
# 27              0.71353
# 28              0.73683
# 29              0.73630

# %%
new_df = df.filter(items=['train/box_loss',	'train/cls_loss',	'train/dfl_loss'])
new_df.tail()
# Out:
#     train/box_loss  train/cls_loss  train/dfl_loss
# 25         0.86723         0.47484         1.20645
# 26         0.85636         0.46362         1.19002
# 27         0.85133         0.45335         1.18438
# 28         0.83444         0.43715         1.16992
# 29         0.82973         0.42307         1.16640

# %%
from PIL import Image

# %%
results = Image.open('/content/drive/MyDrive/miniproject1 68/miniproject/miniproject_yolov12m/results.png')
results
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2400x1200>

# %%
n_matrix = Image.open('/content/drive/MyDrive/miniproject1 68/miniproject/miniproject_yolov12m/confusion_matrix_normalized.png')
n_matrix
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=3000x2250>

# %%
pr = Image.open('/content/drive/MyDrive/miniproject1 68/miniproject/miniproject_yolov12m/BoxPR_curve.png')
pr
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2250x1500>

# %%
f1 = Image.open('/content/drive/MyDrive/miniproject1 68/miniproject/miniproject_yolov12m/BoxF1_curve.png')
f1
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2250x1500>
