# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/miniproject1 68/miniproject/miniproject_yolov12n/results.csv')
df
# Out:
#     epoch      time  train/box_loss  train/cls_loss  train/dfl_loss  \
# 0       1   54.4382         1.41381         2.83056         1.36680
# 1       2   84.8586         1.22273         1.41778         1.24764
# 2       3  115.5650         1.15990         1.20283         1.22689
# 3       4  145.0160         1.14853         1.12331         1.22448
# 4       5  174.5180         1.11989         1.07133         1.20597
# 5       6  204.7310         1.11376         1.02341         1.21268
# 6       7  234.4420         1.08999         0.99520         1.19465
# 7       8  263.9940         1.07248         0.95399         1.19372
# 8       9  294.3210         1.05623         0.91902         1.17769
# 9      10  324.7990         1.05017         0.91487         1.17749
# 10     11  354.7570         1.04778         0.87839         1.16622
# 11     12  384.8010         1.05284         0.87074         1.17458
# 12     13  416.4260         1.03021         0.84445         1.16744
# ...

# %%
new_df = df.filter(items=['epoch','metrics/precision(B)','metrics/recall(B)'	,'metrics/mAP50(B)','metrics/mAP50-95(B)'])
new_df.tail()
# Out:
#     epoch  metrics/precision(B)  metrics/recall(B)  metrics/mAP50(B)  \
# 25     26               0.91945            0.90106           0.93221
# 26     27               0.90359            0.90831           0.92966
# 27     28               0.90128            0.91305           0.92575
# 28     29               0.90538            0.91721           0.93348
# 29     30               0.91067            0.91634           0.93780
#
#     metrics/mAP50-95(B)
# 25              0.71736
# 26              0.72196
# 27              0.72047
# 28              0.72566
# 29              0.72836

# %%
new_df = df.filter(items=['train/box_loss',	'train/cls_loss',	'train/dfl_loss'])
new_df.tail()
# Out:
#     train/box_loss  train/cls_loss  train/dfl_loss
# 25         0.87803         0.56123         1.10122
# 26         0.87029         0.55374         1.09162
# 27         0.86508         0.54873         1.08802
# 28         0.85339         0.52639         1.08506
# 29         0.85287         0.51932         1.07750

# %%
from PIL import Image

# %%
results = Image.open('/content/drive/MyDrive/miniproject1 68/miniproject/miniproject_yolov12n/results.png')
results
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2400x1200>

# %%
n_matrix = Image.open('/content/drive/MyDrive/miniproject1 68/miniproject/miniproject_yolov12n/confusion_matrix_normalized.png')
n_matrix
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=3000x2250>

# %%
pr = Image.open('/content/drive/MyDrive/miniproject1 68/miniproject/miniproject_yolov12n/BoxPR_curve.png')
pr
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2250x1500>

# %%
f1 = Image.open('/content/drive/MyDrive/miniproject1 68/miniproject/miniproject_yolov12n/BoxF1_curve.png')
f1
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2250x1500>
